# %% [markdown]
# # Visualizing Data

# %% [markdown]
# ## Loading paths

# %%
from os import listdir
from PIL import Image as PImage
from IPython.display import Image

def loadImages(path):
    imagesList = listdir(path)
    loadedImages = []
    for image in imagesList:
        img = PImage.open(path + image)
        loadedImages.append(img)
    return loadedImages
    
path = "plots/"
imgs = loadImages(path)

# %% [markdown]
# ## Correlation

# %%
display(imgs[0])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=593x496>

# %% [markdown]
# <font size="4">From the image above we can see that the correlation between gt_corners and rb_corners equals to 1.0, it means that the accuracy of a model is 100%
# <br>
# We can also see the correlation between different features of the dataset
# </font>

# %% [markdown]
# ## Pairwise relationships

# %%
display(imgs[1])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2234x2211>

# %% [markdown]
# ## Scatterplot of gt_corners

# %%
display(imgs[2])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=562x460>

# %% [markdown]
# ## What can also be done

# %% [markdown]
# <font size="4">
# EDA can be performed, but it wasn't a required task
# </font>
